# %%
from torch import nn
from torch.nn import *

from torch.utils.data import DataLoader, ConcatDataset
from torch.utils.tensorboard import SummaryWriter
from torchvision import *

# %%
class ResModule(nn.Module):
    def __init__(self, in_channel, out_channel, use_1x1=False, stride=1):
        super().__init__()
        self.relu = ReLU(inplace=True)
        if use_1x1:
            self.conv3 = Conv2d(in_channel, out_channel, kernel_size=1, stride=stride, padding=0)
        else:
            self.conv3 = None

        self.model = Sequential(
            Conv2d(in_channel, out_channel, kernel_size=3, stride=stride, padding=1),
            BatchNorm2d(out_channel, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            ReLU(inplace=True),
            Conv2d(out_channel, out_channel, kernel_size=3, padding=1),
            BatchNorm2d(out_channel, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        )

    def forward(self, x):
        out = self.model(x)
        if self.conv3:
            x = self.conv3(x)
        out += x
        out = self.relu(out)
        return out



def resnet_block(input_channel, output_channel, resModule_num, firstblock=False):
    blk = []
    for i in range(resModule_num):
        if i == 0 and not firstblock:
            blk.append(ResModule(input_channel, output_channel, True, stride=2))
        else:
            blk.append(ResModule(output_channel, output_channel))
    return blk



class Resnet(nn.Module):
    def __init__(self):
        super(Resnet, self).__init__()  
        self.module = Sequential(
            Conv2d(3, 64, kernel_size=7, stride=2, padding=1, bias=False),
            BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            ReLU(),
            MaxPool2d(kernel_size=3, stride=2, padding=1),
            *resnet_block(64, 64, 3, firstblock=True),
            *resnet_block(64, 128, 4),
            *resnet_block(128, 256, 6),
            *resnet_block(256, 512, 3),
            AdaptiveAvgPool2d((1, 1)),
            Flatten(),
            # Linear(512, 128),
            # ReLU(),
            # Dropout(0.5),
            Linear(512, 2)
        )

    def forward(self, x):
        out = self.module(x)
        return out

# %%
class TransformSubset(torch.utils.data.Subset):
    def __init__(self, dataset, indices, transform=None):
        super().__init__(dataset, indices)
        self.transform = transform

    def __getitem__(self, idx):
        x, y = self.dataset[self.indices[idx]]
        if self.transform:
            x = self.transform(x)
        return x, y
    
IMAGE_SIZE = (224, 224)
# 定义数据增强操作
transform_augmented = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 定义不包含数据增强的转换操作 归一化
transform_plain = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset_path = 'images'
# train_data_strong = datasets.ImageFolder(root=dataset_path, transform=transform_augmented)
all_data = datasets.ImageFolder(root=dataset_path, transform=transform_plain)
train_size = int(0.8 * len(all_data))
test_size = len(all_data) - train_size
train_data, test_data = torch.utils.data.random_split(all_data, [train_size, test_size])
train_data_augmented = TransformSubset(all_data, train_data.indices, transform=transform_augmented)
combined_dataset = ConcatDataset([train_data, train_data_augmented])
print(torch.cuda.is_available())

batch_size = 32
testdata_len = test_size

traindata_load = DataLoader(train_data, batch_size)
testdata_load = DataLoader(test_data, batch_size)

# 创建网络模型
qnet = Resnet()


# 使用显卡
if torch.cuda.is_available():
    qnet = qnet.cuda()
# 损失函数
loss_fn = nn.CrossEntropyLoss()
# 使用显卡
if torch.cuda.is_available():
    loss_fn = loss_fn.cuda()

# s设置参数
train_step = 0
test_step = 0
epoch = 30

# 优化器

learn_rate = 0.001
optimizer = torch.optim.SGD(qnet.parameters(), lr=learn_rate, momentum=0.9, nesterov=False)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=600, gamma=0.3)

# 添加tensorboard
writer = SummaryWriter("./logs/Resnet_au")

qnet.train()
for i in range(epoch):
    print(f"--------第{i + 1}轮训练--------")
    for data in traindata_load:
        imgs, labels = data
        # 使用显卡
        if torch.cuda.is_available():
            imgs = imgs.cuda()
            labels = labels.cuda()
        output = qnet(imgs)
        loss = loss_fn(output, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_step = train_step + 1

        # 学习率更新
        lr_scheduler.step()

        if train_step % 50 == 0:
            print(f"训练次数{train_step},损失值{loss.item()}")
            writer.add_scalar("train_loss{}_{}".format(batch_size, epoch), loss.item(), train_step)

    # 测试
    qnet.eval()

    total_test_loss = 0
    total_accuracy = 0
    with torch.no_grad():
        for data in testdata_load:
            imgs, labels = data
            # 使用显卡
            if torch.cuda.is_available():
                imgs = imgs.cuda()
                labels = labels.cuda()
            output = qnet(imgs)
            loss = loss_fn(output, labels)
            total_test_loss = total_test_loss + loss.item()
            accuracy = (output.argmax(1) == labels).sum()
            total_accuracy = total_accuracy + accuracy
    print(f"整体测试集上的loss{total_test_loss}")
    current_lr = optimizer.param_groups[0]['lr']
    print(f"Current learning rate: {current_lr}")
    print(f"整体测试集上的正确率{total_accuracy / testdata_len}")
    writer.add_scalar("test_loss{}_{}".format(batch_size, epoch), total_test_loss, test_step)
    writer.add_scalar("accuracy{}_{}".format(batch_size, epoch),
                      total_accuracy / testdata_len,
                      test_step)
    test_step = test_step + 1
    # 保存模型
    torch.save(qnet.state_dict(), "qnet_{}.pth".format(i))
    torch.save(qnet, "qnet_{}.pth".format(i))

writer.close()
# Out:
# True
# --------第1轮训练--------
# 训练次数50,损失值0.8402194976806641
# 训练次数100,损失值0.5488109588623047
# 整体测试集上的loss23.301626563072205
# Current learning rate: 0.001
# 整体测试集上的正确率0.6470588445663452
# --------第2轮训练--------
# 训练次数150,损失值0.6280065774917603
# 训练次数200,损失值0.6991361379623413
# 训练次数250,损失值0.5547235608100891
# 整体测试集上的loss20.530587881803513
# Current learning rate: 0.001
# 整体测试集上的正确率0.6877828240394592
# --------第3轮训练--------
# 训练次数300,损失值0.6069490313529968
# 训练次数350,损失值0.5896381139755249
# 训练次数400,损失值0.6752049326896667
# 整体测试集上的loss21.434870302677155
# Current learning rate: 0.001
# 整体测试集上的正确率0.6651583909988403
# --------第4轮训练--------
# 训练次数450,损失值0.6627976894378662
# 训练次数500,损失值0.6537384390830994
# 训练次数550,损失值0.5127174258232117
# 整体测试集上的loss18.486763268709183
# Current learning rate: 0.001
# 整体测试集上的正确率0.7402715086936951
# --------第5轮训练--------
# 训练次数600,损失值0.46639639139175415
# 训练次数650,损失值0.4505273997783661
# 整体测试集上的loss17.55101850628853
# Current learning rate: 0.0003
# 整体测试集上的正确率0.7728506922721863
# --------第6轮训练--------
# 训练次数700,损失值0.42768755555152893
# 训练次数750,损失值0.3334692120552063
# 训练次数800,损失值0.3507404029369354
# 整体测试集上的loss20.019461691379547
# Current learning rate: 0.0003
# 整体测试集上的正确率0.7230769395828247
# --------第7轮训练--------
# 训练次数850,损失值0.43020501732826233
# 训练次数900,损失值0.44519859552383423
# 训练次数950,损失值0.28330135345458984
# 整体测试集上的loss13.680799901485443
# Current learning rate: 0.0003
# 整体测试集上的正确率0.8063348531723022
# --------第8轮训练--------
# 训练次数1000,损失值0.20604020357131958
# 训练次数1050,损失值0.18023346364498138
# 训练次数1100,损失值0.20211872458457947
# 整体测试集上的loss12.503525629639626
# Current learning rate: 0.0003
# 整体测试集上的正确率0.8470588326454163
# --------第9轮训练--------
# 训练次数1150,损失值0.18399792909622192
# 训练次数1200,损失值0.19905829429626465
# 训练次数1250,损失值0.05372807756066322
# 整体测试集上的loss11.135501757264137
# Current learning rate: 8.999999999999999e-05
# 整体测试集上的正确率0.8760181069374084
# --------第10轮训练--------
# 训练次数1300,损失值0.059200216084718704
# 训练次数1350,损失值0.05291736125946045
# 整体测试集上的loss10.915000896900892
# Current learning rate: 8.999999999999999e-05
# 整体测试集上的正确率0.8986425399780273
# --------第11轮训练--------
# 训练次数1400,损失值0.030845152214169502
# 训练次数1450,损失值0.04173775762319565
# 训练次数1500,损失值0.14843954145908356
# 整体测试集上的loss13.37834806740284
# Current learning rate: 8.999999999999999e-05
# 整体测试集上的正确率0.8932126760482788
# --------第12轮训练--------
# 训练次数1550,损失值0.017541395500302315
# 训练次数1600,损失值0.14677944779396057
# 训练次数1650,损失值0.2528291642665863
# 整体测试集上的loss15.30367660522461
# Current learning rate: 8.999999999999999e-05
# 整体测试集上的正确率0.8497737646102905
# --------第13轮训练--------
# 训练次数1700,损失值0.1373954713344574
# 训练次数1750,损失值0.12709598243236542
# 训练次数1800,损失值0.3461885154247284
# 整体测试集上的loss11.988448977470398
# Current learning rate: 2.6999999999999996e-05
# 整体测试集上的正确率0.8968325853347778
# --------第14轮训练--------
# 训练次数1850,损失值0.023856736719608307
# 训练次数1900,损失值0.010001403279602528
# 整体测试集上的loss7.859707407886162
# Current learning rate: 2.6999999999999996e-05
# 整体测试集上的正确率0.9447963833808899
# --------第15轮训练--------
# 训练次数1950,损失值0.0029311254620552063
# 训练次数2000,损失值0.0029557691887021065
# 训练次数2050,损失值0.0016559083014726639
# 整体测试集上的loss8.242325120838359
# Current learning rate: 2.6999999999999996e-05
# 整体测试集上的正确率0.9457013607025146
# --------第16轮训练--------
# 训练次数2100,损失值0.0030897154938429594
# 训练次数2150,损失值0.0013131953310221434
# 训练次数2200,损失值0.0029454645700752735
# 整体测试集上的loss8.492164904717356
# Current learning rate: 2.6999999999999996e-05
# 整体测试集上的正确率0.9457013607025146
# --------第17轮训练--------
# 训练次数2250,损失值0.0012934011174365878
# 训练次数2300,损失值0.0011978034162893891
# 训练次数2350,损失值0.00021865888265892863
# 整体测试集上的loss8.71220025641378
# Current learning rate: 2.6999999999999996e-05
# 整体测试集上的正确率0.9475113153457642
# --------第18轮训练--------
# 训练次数2400,损失值0.001080026151612401
# 训练次数2450,损失值0.0006713162874802947
# 训练次数2500,损失值0.0007272829534485936
# 整体测试集上的loss8.806414071470499
# Current learning rate: 8.099999999999999e-06
# 整体测试集上的正确率0.9457013607025146
# --------第19轮训练--------
# 训练次数2550,损失值0.000767525052651763
# 训练次数2600,损失值0.001238803961314261
# 整体测试集上的loss8.858589103911072
# Current learning rate: 8.099999999999999e-06
# 整体测试集上的正确率0.9475113153457642
# --------第20轮训练--------
# 训练次数2650,损失值0.0007853769930079579
# 训练次数2700,损失值0.0008777569746598601
# 训练次数2750,损失值0.001577003044076264
# 整体测试集上的loss8.911872876808047
# Current learning rate: 8.099999999999999e-06
# 整体测试集上的正确率0.9475113153457642
# --------第21轮训练--------
# 训练次数2800,损失值0.0009102285257540643
# 训练次数2850,损失值0.0008200948359444737
# 训练次数2900,损失值0.00044344316120259464
# 整体测试集上的loss8.959891820442863
# Current learning rate: 8.099999999999999e-06
# 整体测试集上的正确率0.9475113153457642
# --------第22轮训练--------
# 训练次数2950,损失值0.0007799213635735214
# 训练次数3000,损失值0.0004212850471958518
# 训练次数3050,损失值0.0007193692727014422
# 整体测试集上的loss8.992959973285906
# Current learning rate: 2.4299999999999996e-06
# 整体测试集上的正确率0.9475113153457642
# --------第23轮训练--------
# 训练次数3100,损失值0.000906558008864522
# 训练次数3150,损失值0.0024964320473372936
# 整体测试集上的loss9.006782401236705
# Current learning rate: 2.4299999999999996e-06
# 整体测试集上的正确率0.9475113153457642
# --------第24轮训练--------
# 训练次数3200,损失值0.0006245876429602504
# 训练次数3250,损失值0.0006270711310207844
# 训练次数3300,损失值0.0009704193216748536
# 整体测试集上的loss9.020450313342735
# Current learning rate: 2.4299999999999996e-06
# 整体测试集上的正确率0.9475113153457642
# --------第25轮训练--------
# 训练次数3350,损失值0.0007260449347086251
# 训练次数3400,损失值0.0007218652172014117
# 训练次数3450,损失值0.0008396182674914598
# 整体测试集上的loss9.034178373287432
# Current learning rate: 2.4299999999999996e-06
# 整体测试集上的正确率0.9475113153457642
# --------第26轮训练--------
# 训练次数3500,损失值0.0007558311917819083
# 训练次数3550,损失值0.0007071999716572464
# 训练次数3600,损失值0.0004963856190443039
# 整体测试集上的loss9.044919221661985
# Current learning rate: 7.289999999999998e-07
# 整体测试集上的正确率0.9475113153457642
# --------第27轮训练--------
# 训练次数3650,损失值0.00037400759174488485
# 训练次数3700,损失值0.0009816329693421721
# 训练次数3750,损失值0.0005640981835313141
# 整体测试集上的loss9.048429277376272
# Current learning rate: 7.289999999999998e-07
# 整体测试集上的正确率0.9475113153457642
# --------第28轮训练--------
# 训练次数3800,损失值0.0012104717316105962
# 训练次数3850,损失值0.0004055485187564045
# 整体测试集上的loss9.047013876377605
# Current learning rate: 7.289999999999998e-07
# 整体测试集上的正确率0.9475113153457642
# --------第29轮训练--------
# 训练次数3900,损失值0.0012716676574200392
# 训练次数3950,损失值0.000972259440459311
# 训练次数4000,损失值0.0005037093069404364
# 整体测试集上的loss9.051138832233846
# Current learning rate: 7.289999999999998e-07
# 整体测试集上的正确率0.9475113153457642
# --------第30轮训练--------
# 训练次数4050,损失值0.000514747342094779
# 训练次数4100,损失值0.0006025279872119427
# 训练次数4150,损失值0.0003859333519358188
# 整体测试集上的loss9.053936546901241
# Current learning rate: 7.289999999999998e-07
# 整体测试集上的正确率0.9475113153457642
